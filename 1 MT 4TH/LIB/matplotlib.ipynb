# %%
##data visualization -- graphs and plots
# !pip install matplotlib seaborn

# %%
import numpy  as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
arr1 = np.random.randint(20000,40000,100)
arr1
# Out:
# array([34785, 39410, 30950, 39882, 25862, 35537, 35775, 25535, 31241,
#        20553, 34214, 25783, 25183, 39102, 39492, 33366, 27821, 20165,
#        34691, 39917, 21752, 20422, 31034, 31906, 23116, 21929, 37292,
#        33762, 33204, 30001, 38483, 20793, 24273, 37944, 24275, 23903,
#        31475, 33880, 30766, 34985, 27981, 38798, 38630, 26794, 24129,
#        34187, 23573, 34082, 23836, 37555, 31213, 29235, 26343, 26272,
#        33662, 28204, 29713, 24901, 21441, 32946, 38572, 33226, 21841,
#        21545, 21142, 21633, 37874, 27916, 35948, 20733, 22261, 37261,
#        38692, 30525, 23845, 34942, 33243, 36162, 20827, 20029, 26246,
#        20484, 21966, 21158, 23377, 30373, 36394, 23468, 24468, 30510,
#        29258, 24497, 21627, 21670, 23750, 37693, 22390, 36791, 20303,
#        21813])

# %%
#linechart ///lineplot 
plt.plot(arr1) 
plt.show()

# %%
arr1.sort()
plt.plot(arr1)

# %%
x= [1,2,3,4,5]
y = [1,10,9,40,25]
plt.plot(x,y,marker = "D",ms = 10,mfc = "red",mec="black",color = "green",lw = 3,ls = "-.",label = "line plot",alpha = 0.9)
plt.title("line plot")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.legend()



plt.show()

# %%
##scatter plot 
plt.scatter(x,y,marker = "D",s = 100,c = "red",alpha = 0.9,label = "scatter plot",edgecolor = "black",linewidth = 3)

# %%
df = pd.read_csv("Used_Bikes.csv")
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
# plt.scatter(df["price"],df["kms_driven"])
plt.scatter(df.price,df.age)

# %%
df1 = sns.load_dataset("tips")
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
##bar chart 
x = ["mp","rj","up","mb"]
y = [1000,4000,8000,12000]
colours = ["red","green","blue","yellow"]
hatch_patterns = ['/', '\\', '|', '-'] 

plt.bar(x,y,color = colours,label = x,width = 0.5,edgecolor = "black",linewidth = 3,alpha = 0.9,hatch = hatch_patterns,zorder = 3)
plt.legend()
plt.grid()

# %%
plt.barh(x,y,color = colours)
# Out:
# <BarContainer object of 4 artists>

# %%
##histogram -- distribution of data in bins(intervals)
data = np.random.randn(1000)

plt.hist(data, bins=30, color='skyblue', edgecolor='black',hatch='//')
plt.show()

# %%
##piechart 
labels = ['A', 'B', 'C', 'D']
sizes = [30, 15, 45, 10]
explodes = (0.1,0,0,0.1)

plt.pie(sizes, labels=labels, autopct='%1.2f%%', colors=['red', 'blue', 'green', 'yellow'],shadow=True,explode=explodes)
plt.title("Pie Chart")
plt.show()

# %%
## save a plot 
plt.savefig("plot.pdf",)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)

plt.figure(figsize=(10, 5))

plt.subplot(2, 2, 1)  # 2 rows, 2 columns, 1st subplot
plt.plot(x, np.sin(x))
plt.title("Sin(x)")

plt.subplot(2, 2, 2)  # 2nd subplot
plt.plot(x, np.cos(x))
plt.title("Cos(x)")

plt.subplot(2, 2, 3)  # 3rd subplot
plt.plot(x, np.tan(x))
plt.title("Tan(x)")

plt.subplot(2, 2, 4)  # 4th subplot
plt.plot(x, np.exp(-x))
plt.title("Exp(-x)")

plt.tight_layout()  # Adjust layout for better spacing
plt.show()

# %%
##subplots -- multiple plots in a single figure

x = np.linspace(0, 10, 100)
plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)  # 2 rows, 2 columns, 1st subplot

plt.plot(x, np.sin(x))
plt.title("Sin(x)")

plt.subplot(2,2,2)  # 2nd subplot
plt.plot(x, np.cos(x))
plt.title("Cos(x)")

plt.subplot(2,2,3)  # 3rd subplot
plt.plot(x, np.tan(x))
plt.title("Tan(x)")

plt.subplot(2,2,4)  # 4th subplot
plt.plot(x, np.exp(-x))
plt.title("Exp(-x)")

plt.tight_layout()  # Adjust layout for better spacing
plt.show()
