# %%
###data manipulation and analysis 
##large data set

# %%
import pandas as pd

# %%
df = pd.read_csv('Used_Bikes.csv')
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
#              owner   age  power          brand
# 0      First Owner   3.0  110.0            TVS
# 1      First Owner   4.0  350.0  Royal Enfield
# 2      First Owner   8.0  675.0        Triumph
# 3      First Owner   4.0  180.0            TVS
# 4      First Owner   3.0  150.0         Yamaha
# ...            ...   ...    ...            ...
# 32643  First Owner   4.0  100.0           Hero
# 32644  First Owner   9.0  180.0            TVS
# 32645  First Owner   6.0  220.0          Bajaj
# 32646  First Owner  16.0  125.0           Hero
# 32647  First Owner  13.0  150.0          Bajaj
#
# [32648 rows x 8 columns]

# %%
##dataframe -- 2d tabular data structure
##series  --- 1d

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
##createing a dataframme 
dt = {
    "name" : ["a","b","c"],
    "class" : [1,2,3],
    "age" : [10,15,20]
}

df1 = pd.DataFrame(dt)
df1
# Out:
#   name  class  age
# 0    a      1   10
# 1    b      2   15
# 2    c      3   20

# %%
import numpy as np 

arr = np.arange(60).reshape(12,5)
arr
df2 = pd.DataFrame(arr,columns=["a","b","c","d","e"])
df2
# Out:
#      a   b   c   d   e
# 0    0   1   2   3   4
# 1    5   6   7   8   9
# 2   10  11  12  13  14
# 3   15  16  17  18  19
# 4   20  21  22  23  24
# 5   25  26  27  28  29
# 6   30  31  32  33  34
# 7   35  36  37  38  39
# 8   40  41  42  43  44
# 9   45  46  47  48  49
# 10  50  51  52  53  54
# 11  55  56  57  58  59

# %%
df.head()
# df.tail()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
# type(df["age"])
df["age"].dtype
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# bike_name      object
# price         float64
# city           object
# kms_driven    float64
# owner          object
# age           float64
# power         float64
# brand          object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
##multiple fetch 
df[["age","price"]]
# Out:
#         age     price
# 0       3.0   35000.0
# 1       4.0  119900.0
# 2       8.0  600000.0
# 3       4.0   65000.0
# 4       3.0   80000.0
# ...     ...       ...
# 32643   4.0   39000.0
# 32644   9.0   30000.0
# 32645   6.0   60000.0
# 32646  16.0   15600.0
# 32647  13.0   22000.0
#
# [32648 rows x 2 columns]

# %%
##indexing 
df[0:10]
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
#
#           owner  age  power          brand
# 0   First Owner  3.0  110.0            TVS
# 1   First Owner  4.0  350.0  Royal Enfield
# 2   First Owner  8.0  675.0        Triumph
# 3   First Owner  4.0  180.0            TVS
# 4   First Owner  3.0  150.0         Yamaha
# 5   First Owner  6.0  150.0         Yamaha
# 6   First Owner  3.0  160.0          Honda
# 7   First Owner  3.0  100.0           Hero
# 8   First Owner  3.0  350.0  Royal Enfield
# 9  Second Owner  7.0  500.0  Royal Enfield

# %%
##indexing -- loc -- location based indexing 
# , iloc -- interger based

# %%
##iloc -- [row start:end:skip,"columns start:end:skip]
df.iloc[0:11:2,0:5]
# Out:
#                                bike_name     price       city  kms_driven  \
# 0     TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 2                   Triumph Daytona 675R  600000.0      Delhi       110.0
# 4   Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 6          Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 8      Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 10              Yamaha YZF-R15 2.0 150cc   72000.0  Bangalore     20000.0
#
#           owner
# 0   First Owner
# 2   First Owner
# 4   First Owner
# 6   First Owner
# 8   First Owner
# 10  First Owner

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.loc[0:10,["bike_name","brand"]]
# Out:
#                                    bike_name          brand
# 0         TVS Star City Plus Dual Tone 110cc            TVS
# 1                Royal Enfield Classic 350cc  Royal Enfield
# 2                       Triumph Daytona 675R        Triumph
# 3                       TVS Apache RTR 180cc            TVS
# 4       Yamaha FZ S V 2.0 150cc-Ltd. Edition         Yamaha
# 5                           Yamaha FZs 150cc         Yamaha
# 6              Honda CB Hornet 160R  ABS DLX          Honda
# 7        Hero Splendor Plus Self Alloy 100cc           Hero
# 8          Royal Enfield Thunderbird X 350cc  Royal Enfield
# 9   Royal Enfield Classic Desert Storm 500cc  Royal Enfield
# 10                  Yamaha YZF-R15 2.0 150cc         Yamaha

# %%
##predefine functions

df[["price"]].max()
df[["price"]].min()
df[["price"]].mean()
df[["price"]].sum()
df[["price"]].std()
# Out:
# price    90718.595205
# dtype: float64

# %%
df.max()
# Out:
# bike_name     Yezdi Classic 250cc
# price                   1900000.0
# city                     Zirakpur
# kms_driven               750000.0
# owner                 Third Owner
# age                          63.0
# power                      1800.0
# brand                       Yezdi
# dtype: object

# %%
df["city"].unique()
df["city"].nunique()
df["city"].value_counts()
# Out:
# city
# Delhi         7318
# Bangalore     2723
# Mumbai        2591
# Hyderabad     2160
# Pune          1724
#               ...
# Berhampore       1
# Silvasa          1
# Hospet           1
# Palai            1
# Sidhi            1
# Name: count, Length: 443, dtype: int64

# %%
df.head(10)
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
#
#           owner  age  power          brand
# 0   First Owner  3.0  110.0            TVS
# 1   First Owner  4.0  350.0  Royal Enfield
# 2   First Owner  8.0  675.0        Triumph
# 3   First Owner  4.0  180.0            TVS
# 4   First Owner  3.0  150.0         Yamaha
# 5   First Owner  6.0  150.0         Yamaha
# 6   First Owner  3.0  160.0          Honda
# 7   First Owner  3.0  100.0           Hero
# 8   First Owner  3.0  350.0  Royal Enfield
# 9  Second Owner  7.0  500.0  Royal Enfield

# %%
df.columns
# Out:
# Index(['bike_name', 'price', 'city', 'kms_driven', 'owner', 'age', 'power',
#        'brand'],
#       dtype='object')

# %%
df["owner"].value_counts()
# Out:
# owner
# First Owner             29964
# Second Owner             2564
# Third Owner               108
# Fourth Owner Or More       12
# Name: count, dtype: int64

# %%
df[df["owner"] == "Fourth Owner Or More"]
# Out:
#                                          bike_name     price       city  \
# 2146                   Royal Enfield‎ Bullet 350cc   85990.0     Raipur
# 2999               Royal Enfield Thunderbird 350cc   95000.0      Delhi
# 3637                            Bajaj Pulsar 150cc   11000.0  Bangalore
# 4120                           Bajaj Avenger 220cc   37000.0  Ahmedabad
# 5221                        Yamaha Gladiator 125cc   20000.0  Bangalore
# 5456                        Yamaha Gladiator 125cc   20000.0  Bangalore
# 5568  Royal Enfield Classic 350cc-Redditch Edition  141000.0       Pune
# 6138                    Royal Enfield Bullet 350cc   89000.0    Lucknow
# 6755                    Royal Enfield Bullet 350cc   89000.0    Lucknow
# 6985                   Royal Enfield Classic 350cc   90000.0  Ghaziabad
# 7038            Royal Enfield Bullet Electra 350cc   35000.0      Delhi
# 9028                       Hero Passion Plus 100cc   23000.0   Anantnag
#
#       kms_driven                 owner   age  power          brand
# 2146     19000.0  Fourth Owner Or More  37.0  350.0  Royal Enfield
# 2999      9392.0  Fourth Owner Or More   6.0  350.0  Royal Enfield
# 3637     58000.0  Fourth Owner Or More  14.0  150.0          Bajaj
# 4120     30334.0  Fourth Owner Or More   7.0  220.0          Bajaj
# 5221     38500.0  Fourth Owner Or More  12.0  125.0         Yamaha
# 5456     38500.0  Fourth Owner Or More  12.0  125.0         Yamaha
# 5568     10825.0  Fourth Owner Or More   4.0  350.0  Royal Enfield
# 6138     19890.0  Fourth Owner Or More  27.0  350.0  Royal Enfield
# 6755     19890.0  Fourth Owner Or More  27.0  350.0  Royal Enfield
# 6985     43740.0  Fourth Owner Or More   7.0  350.0  Royal Enfield
# 7038     60000.0  Fourth Owner Or More  18.0  350.0  Royal Enfield
# 9028      2009.0  Fourth Owner Or More  12.0  100.0           Hero

# %%
##city -- delhi 

delhi=df[df["city"] == "Delhi"]
##delhi -- price 60000
delhi_under_60k=delhi[delhi["price"] <= 60000.0]

# %%
delhi_under_60k
# Out:
#                                  bike_name    price   city  kms_driven  \
# 5                         Yamaha FZs 150cc  53499.0  Delhi     25000.0
# 7      Hero Splendor Plus Self Alloy 100cc  45000.0  Delhi     12645.0
# 13                     Bajaj Discover 100M  29499.0  Delhi     20000.0
# 14                     Bajaj Discover 125M  29900.0  Delhi     20000.0
# 19                     Bajaj Discover 125M  29900.0  Delhi     20000.0
# ...                                    ...      ...    ...         ...
# 32637                   Bajaj Pulsar 150cc  25000.0  Delhi     32588.0
# 32640               Hero Passion Pro 100cc  32000.0  Delhi     12000.0
# 32641                  Bajaj Avenger 220cc  41000.0  Delhi     20245.0
# 32643               Hero Passion Pro 100cc  39000.0  Delhi     22000.0
# 32645             Bajaj Avenger Street 220  60000.0  Delhi     20373.0
#
#               owner   age  power   brand
# 5       First Owner   6.0  150.0  Yamaha
# 7       First Owner   3.0  100.0    Hero
# 13      First Owner   8.0  100.0   Bajaj
# 14      First Owner   7.0  125.0   Bajaj
# 19      First Owner   7.0  125.0   Bajaj
# ...             ...   ...    ...     ...
# 32637   First Owner   9.0  150.0   Bajaj
# 32640   First Owner   6.0  100.0    Hero
# 32641  Second Owner  11.0  220.0   Bajaj
# 32643   First Owner   4.0  100.0    Hero
# 32645   First Owner   6.0  220.0   Bajaj
#
# [5221 rows x 8 columns]

# %%
##multiple conditions 
#brand = "tvs", age <= 3 , power <=110

df[(df["brand"] =="TVS")  &  (df["age"] <=3) & (df["power"]<=110.0)]
# Out:
#                                bike_name    price         city  kms_driven  \
# 0     TVS Star City Plus Dual Tone 110cc  35000.0    Ahmedabad     17654.0
# 986                      TVS Sport 100cc  34000.0        Delhi      8048.0
# 1084                     TVS Sport 100cc  34000.0        Delhi      8048.0
# 2360           TVS Victor 110cc Disc SBT  54000.0        Delhi      6000.0
# 2381           TVS Victor 110cc Disc SBT  54000.0        Delhi      6000.0
# 2494                     TVS Sport 100cc  39900.0    Bangalore     15000.0
# 2710                    TVS Victor 110cc  40000.0      Chennai     12530.0
# 3362                     TVS Sport 100cc  32000.0    Faridabad     15820.0
# 4114           TVS Radeon 110cc Drum SBT  38000.0        Delhi     21249.0
# 4251            TVS Star City Plus 110cc  51000.0    Ahmedabad     12000.0
# 5468                     TVS Sport 100cc  38000.0        Noida      8718.0
# 6310                     TVS Sport 100cc  34000.0       Jaipur      4474.0
# 6656            TVS Star City Plus 110cc  44000.0        Delhi      5400.0
# 6998               TVS Victor 110cc Disc  42985.0        Surat      6000.0
# 7055                     TVS Sport 100cc  46000.0    Faridabad      6222.0
# 7138                     TVS Sport 100cc  34000.0       Jaipur      4474.0
# 7190            TVS Star City Plus 110cc  44000.0        Delhi      5400.0
# 7672                     TVS Sport 100cc  32000.0      Gurgaon     23000.0
# 7975            TVS Star City Plus 110cc  45000.0  Chitradurga      1363.0
# 8251  TVS Star City Plus Dual Tone 110cc  54000.0       Mumbai       100.0
# 8423                     TVS Sport 100cc  42900.0       Jhansi      5000.0
# 8538                     TVS Sport 100cc  42900.0       Jhansi      5000.0
# 8562           TVS Radeon 110cc Drum SBT  46000.0    Ahmedabad      9235.0
# 8640           TVS Radeon 110cc Drum SBT  46000.0    Ahmedabad      9235.0
# 9322           TVS Radeon 110cc Drum SBT  58000.0        Delhi      4020.0
#
#             owner  age  power brand
# 0     First Owner  3.0  110.0   TVS
# 986   First Owner  3.0  100.0   TVS
# 1084  First Owner  3.0  100.0   TVS
# 2360  First Owner  2.0  110.0   TVS
# 2381  First Owner  2.0  110.0   TVS
# 2494  First Owner  3.0  100.0   TVS
# 2710  First Owner  3.0  110.0   TVS
# 3362  First Owner  3.0  100.0   TVS
# 4114  First Owner  3.0  110.0   TVS
# 4251  First Owner  2.0  110.0   TVS
# 5468  First Owner  3.0  100.0   TVS
# 6310  First Owner  3.0  100.0   TVS
# 6656  First Owner  3.0  110.0   TVS
# 6998  First Owner  3.0  110.0   TVS
# 7055  First Owner  2.0  100.0   TVS
# 7138  First Owner  3.0  100.0   TVS
# 7190  First Owner  3.0  110.0   TVS
# 7672  First Owner  3.0  100.0   TVS
# 7975  First Owner  3.0  110.0   TVS
# 8251  First Owner  3.0  110.0   TVS
# 8423  First Owner  3.0  100.0   TVS
# 8538  First Owner  3.0  100.0   TVS
# 8562  First Owner  3.0  110.0   TVS
# 8640  First Owner  3.0  110.0   TVS
# 9322  First Owner  2.0  110.0   TVS

# %%
##data cleaning 

##null values 
df.isnull().sum()
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
##null values delete 
df.dropna(inplace=True)

# %%
##duplicates check 
df.duplicated().sum()
# Out:
# np.int64(25324)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv("cleaned_data.csv",index=False)

# %%
##sort values 
df.sort_values(by = ["price"],ascending=False)
# Out:
#                         bike_name      price       city  kms_driven  \
# 367   Indian Chief Classic 1800cc  1900000.0    Chennai      1700.0
# 4864            BMW S 1000 RR Pro  1800000.0      Delhi      2600.0
# 7671         Yamaha YZF-R1 1000cc  1550000.0      Delhi      9800.0
# 3016            BMW S 1000 XR Pro  1500000.0      Delhi     18000.0
# 6872           MV Agusta F3 800cc  1500000.0      Hubli      2000.0
# ...                           ...        ...        ...         ...
# 4923           Bajaj Pulsar 150cc     6700.0      Delhi     81000.0
# 4922           Bajaj Pulsar 150cc     6400.0      Delhi    100000.0
# 1382              TVS Flame 125cc     5800.0  Ghaziabad     25000.0
# 9194          Hero Ambition 135cc     5000.0      Delhi     82178.0
# 4960         LML Freedom DX 110cc     4400.0    Godhara     55000.0
#
#              owner   age   power   brand
# 367    First Owner   6.0  1800.0  Indian
# 4864   First Owner   4.0  1000.0     BMW
# 7671  Second Owner   6.0  1000.0  Yamaha
# 3016   First Owner   4.0  1000.0     BMW
# 6872   First Owner   3.0   800.0      MV
# ...            ...   ...     ...     ...
# 4923   First Owner  17.0   150.0   Bajaj
# 4922   First Owner  18.0   150.0   Bajaj
# 1382   First Owner  13.0   125.0     TVS
# 9194   First Owner  18.0   135.0    Hero
# 4960   First Owner  16.0   110.0     LML
#
# [7324 rows x 8 columns]

# %%
df.sort_index()
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# 0     First Owner  3.0  110.0              TVS
# 1     First Owner  4.0  350.0    Royal Enfield
# 2     First Owner  8.0  675.0          Triumph
# 3     First Owner  4.0  180.0              TVS
# 4     First Owner  3.0  150.0           Yamaha
# ...           ...  ...    ...              ...
# 9362  First Owner  8.0  150.0             Hero
# 9369  First Owner  9.0  220.0            Bajaj
# 9370  First Owner  4.0  750.0  Harley-Davidson
# 9371  First Owner  4.0  400.0            Bajaj
# 9372  First Owner  5.0  220.0            Bajaj
#
# [7324 rows x 8 columns]

# %%
##nan values

dt = {
    "name" : ["a","b","c",np.nan],
    "class" : [1,2,3,4],
    "age" : [10,15,20,np.nan]
}
df1 = pd.DataFrame(dt)
df1
# Out:
#   name  class   age
# 0    a      1  10.0
# 1    b      2  15.0
# 2    c      3  20.0
# 3  NaN      4   NaN

# %%
##check nan values 
df1.isnull().sum().sum()
# Out:
# np.int64(2)

# %%
##drop 
df1.dropna()
df1.dropna(axis=1)
# Out:
#    class
# 0      1
# 1      2
# 2      3
# 3      4

# %%
##fill nan values -- constant , mean , median
df1.fillna(0)
# Out:
#   name  class   age
# 0    a      1  10.0
# 1    b      2  15.0
# 2    c      3  20.0
# 3    0      4   0.0

# %%
df1.fillna(df1.mean())
df1.fillna(df1.median())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[136], line 1
# ----> 1 df1.fillna(df1.mean())
#       2 df1.fillna(df1.median())
#
# File c:\Users\jaikr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694     if isinstance(result, Series):
#   11695         result = result.__finalize__(self, method="mean")
#
# File c:\Users\jaikr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
#   12421         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422     )
#
# File c:\Users\jaikr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12373 nv.validate_func(name, (), kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File c:\Users\jaikr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11562, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11558     df = df.T
#   11560 # After possibly _get_data and transposing, we are now in the
#   11561 #  simple case where we can use BlockManager.reduce
# > 11562 res = df._mgr.reduce(blk_func)
#   11563 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11564 if out_dtype is not None and out.dtype != "boolean":
#
# File c:\Users\jaikr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1500, in BlockManager.reduce(self, func)
#    1498 res_blocks: list[Block] = []
#    1499 for blk in self.blocks:
# -> 1500     nbs = blk.reduce(func)
#    1501     res_blocks.extend(nbs)
#    1503 index = Index([None])  # placeholder
#
# File c:\Users\jaikr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:404, in Block.reduce(self, func)
#     398 @final
#     399 def reduce(self, func) -> list[Block]:
#     400     # We will apply the function and reshape the result into a single-row
#     401     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     402     assert self.ndim == 2
# --> 404     result = func(self.values)
#     406     if self.values.ndim == 1:
#     407         res_values = result
#
# File c:\Users\jaikr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11481, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   11479         return np.array([result])
#   11480 else:
# > 11481     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File c:\Users\jaikr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\jaikr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File c:\Users\jaikr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:719, in nanmean(values, axis, skipna, mask)
#     716     dtype_count = dtype
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 719 the_sum = values.sum(axis, dtype=dtype_sum)
#     720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File c:\Users\jaikr\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\_methods.py:52, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      50 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      51          initial=_NoValue, where=True):
# ---> 52     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "int") to str

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
# df.loc[0:10,["price"]] = np.nan
# df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc       NaN  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc       NaN      Delhi     11000.0
# 2                     Triumph Daytona 675R       NaN      Delhi       110.0
# 3                     TVS Apache RTR 180cc       NaN  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition       NaN  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# 0     First Owner  3.0  110.0              TVS
# 1     First Owner  4.0  350.0    Royal Enfield
# 2     First Owner  8.0  675.0          Triumph
# 3     First Owner  4.0  180.0              TVS
# 4     First Owner  3.0  150.0           Yamaha
# ...           ...  ...    ...              ...
# 9362  First Owner  8.0  150.0             Hero
# 9369  First Owner  9.0  220.0            Bajaj
# 9370  First Owner  4.0  750.0  Harley-Davidson
# 9371  First Owner  4.0  400.0            Bajaj
# 9372  First Owner  5.0  220.0            Bajaj
#
# [7324 rows x 8 columns]

# %%
df.fillna(df["price"].mean())
# df.fillna(df["price"].median())
# Out:
#                                  bike_name          price       city  \
# 0       TVS Star City Plus Dual Tone 110cc   84821.726378  Ahmedabad
# 1              Royal Enfield Classic 350cc   84821.726378      Delhi
# 2                     Triumph Daytona 675R   84821.726378      Delhi
# 3                     TVS Apache RTR 180cc   84821.726378  Bangalore
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   84821.726378  Bangalore
# ...                                    ...            ...        ...
# 9362             Hero Hunk Rear Disc 150cc   25000.000000      Delhi
# 9369                   Bajaj Avenger 220cc   35000.000000  Bangalore
# 9370        Harley-Davidson Street 750 ABS  450000.000000    Jodhpur
# 9371                 Bajaj Dominar 400 ABS  139000.000000  Hyderabad
# 9372              Bajaj Avenger Street 220   80000.000000  Hyderabad
#
#       kms_driven        owner  age  power            brand
# 0        17654.0  First Owner  3.0  110.0              TVS
# 1        11000.0  First Owner  4.0  350.0    Royal Enfield
# 2          110.0  First Owner  8.0  675.0          Triumph
# 3        16329.0  First Owner  4.0  180.0              TVS
# 4        10000.0  First Owner  3.0  150.0           Yamaha
# ...          ...          ...  ...    ...              ...
# 9362     48587.0  First Owner  8.0  150.0             Hero
# 9369     60000.0  First Owner  9.0  220.0            Bajaj
# 9370      3430.0  First Owner  4.0  750.0  Harley-Davidson
# 9371     21300.0  First Owner  4.0  400.0            Bajaj
# 9372      7127.0  First Owner  5.0  220.0            Bajaj
#
# [7324 rows x 8 columns]

# %%
##
df["increased_price"]=df["price"] + 5000

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand  increased_price
# 0  First Owner  3.0  110.0            TVS          40000.0
# 1  First Owner  4.0  350.0  Royal Enfield         124900.0
# 2  First Owner  8.0  675.0        Triumph         605000.0
# 3  First Owner  4.0  180.0            TVS          70000.0
# 4  First Owner  3.0  150.0         Yamaha          85000.0

# %%
##drop column 
df.drop("increased_price",axis=1)
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# 0     First Owner  3.0  110.0              TVS
# 1     First Owner  4.0  350.0    Royal Enfield
# 2     First Owner  8.0  675.0          Triumph
# 3     First Owner  4.0  180.0              TVS
# 4     First Owner  3.0  150.0           Yamaha
# ...           ...  ...    ...              ...
# 9362  First Owner  8.0  150.0             Hero
# 9369  First Owner  9.0  220.0            Bajaj
# 9370  First Owner  4.0  750.0  Harley-Davidson
# 9371  First Owner  4.0  400.0            Bajaj
# 9372  First Owner  5.0  220.0            Bajaj
#
# [7324 rows x 8 columns]

# %%
df.rename(columns={"price":"new_price"})
# Out:
#                                  bike_name  new_price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc    35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc   119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R   600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc    65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition    80000.0  Bangalore     10000.0
# ...                                    ...        ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc    25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc    35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS   450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS   139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220    80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand  increased_price
# 0     First Owner  3.0  110.0              TVS          40000.0
# 1     First Owner  4.0  350.0    Royal Enfield         124900.0
# 2     First Owner  8.0  675.0          Triumph         605000.0
# 3     First Owner  4.0  180.0              TVS          70000.0
# 4     First Owner  3.0  150.0           Yamaha          85000.0
# ...           ...  ...    ...              ...              ...
# 9362  First Owner  8.0  150.0             Hero          30000.0
# 9369  First Owner  9.0  220.0            Bajaj          40000.0
# 9370  First Owner  4.0  750.0  Harley-Davidson         455000.0
# 9371  First Owner  4.0  400.0            Bajaj         144000.0
# 9372  First Owner  5.0  220.0            Bajaj          85000.0
#
# [7324 rows x 9 columns]

# %%
##groupby --
owner_group = df.groupby("owner")

# %%
df["owner"].value_counts()
# Out:
# owner
# First Owner             6642
# Second Owner             588
# Third Owner               84
# Fourth Owner Or More      10
# Name: count, dtype: int64

# %%
owner_group.get_group("First Owner")
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand  increased_price
# 0     First Owner  3.0  110.0              TVS          40000.0
# 1     First Owner  4.0  350.0    Royal Enfield         124900.0
# 2     First Owner  8.0  675.0          Triumph         605000.0
# 3     First Owner  4.0  180.0              TVS          70000.0
# 4     First Owner  3.0  150.0           Yamaha          85000.0
# ...           ...  ...    ...              ...              ...
# 9362  First Owner  8.0  150.0             Hero          30000.0
# 9369  First Owner  9.0  220.0            Bajaj          40000.0
# 9370  First Owner  4.0  750.0  Harley-Davidson         455000.0
# 9371  First Owner  4.0  400.0            Bajaj         144000.0
# 9372  First Owner  5.0  220.0            Bajaj          85000.0
#
# [6642 rows x 9 columns]

# %%
##
# df["price"].max()
##aggregate function
owner_group["age"].agg(max_age = "max",min_age="min",mean_age="mean")
# Out:
#                       max_age  min_age   mean_age
# owner
# First Owner              43.0      1.0   6.446101
# Fourth Owner Or More     37.0      4.0  14.400000
# Second Owner             63.0      2.0   8.290816
# Third Owner              43.0      4.0  10.928571
